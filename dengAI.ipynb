# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Cargar datos

# %%
features_train = pd.read_csv("dengue_features_train.csv")
labels_train = pd.read_csv("dengue_labels_train.csv")
features_test = pd.read_csv("dengue_features_test.csv")
submission_format = pd.read_csv("submission_format.csv")

# %% [markdown]
# Unir y etiquetar datos

# %%
df_train = features_train.merge(labels_train, on=["city", "year", "weekofyear"])

# %% [markdown]
# Visualizar

# %%
display(df_train.head())
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                             73.365714                         12.42
# ...

# %%
print(df_train.info())
print(df_train.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   1456 non-null   object
#  1   year                                   1456 non-null   int64
#  2   weekofyear                             1456 non-null   int64
#  3   week_start_date                        1456 non-null   object
#  4   ndvi_ne                                1262 non-null   float64
#  5   ndvi_nw                                1404 non-null   float64
#  6   ndvi_se                                1434 non-null   float64
#  7   ndvi_sw                                1434 non-null   float64
#  8   precipitation_amt_mm                   1443 non-null   float64
#  9   reanalysis_air_temp_k                  1446 non-null   float64
# ...

# %%
display(df_train.describe())
# Out:
#               year   weekofyear      ndvi_ne      ndvi_nw      ndvi_se  \
# count  1456.000000  1456.000000  1262.000000  1404.000000  1434.000000
# mean   2001.031593    26.503434     0.142294     0.130553     0.203783
# std       5.408314    15.019437     0.140531     0.119999     0.073860
# min    1990.000000     1.000000    -0.406250    -0.456100    -0.015533
# 25%    1997.000000    13.750000     0.044950     0.049217     0.155087
# 50%    2002.000000    26.500000     0.128817     0.121429     0.196050
# 75%    2005.000000    39.250000     0.248483     0.216600     0.248846
# max    2010.000000    53.000000     0.508357     0.454429     0.538314
#
#            ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# count  1434.000000           1443.000000            1446.000000
# mean      0.202305             45.760388             298.701852
# std       0.083903             43.715537               1.362420
# min      -0.063457              0.000000             294.635714
# ...

# %%
plt.figure(figsize=(12, 5))
sns.histplot(df_train[df_train['city'] == "sj"]['total_cases'], bins=30, kde=True, color="blue", label="San Juan")
sns.histplot(df_train[df_train['city'] == "iq"]['total_cases'], bins=30, kde=True, color="red", label="Iquitos")
plt.legend()
plt.xlabel("Total Cases")
plt.ylabel("Frequency")
plt.title("Distribución de casos de dengue por ciudad")
plt.show()

# %%
# Verificar los tipos de datos en features_train
print(features_train.dtypes)

# Identificar columnas que no sean numéricas
non_numeric_cols = features_train.select_dtypes(exclude=['number']).columns
print("Columnas no numéricas:", non_numeric_cols)

# Mostrar algunas filas problemáticas
print(features_train[non_numeric_cols].head())
# Out:
# city                                      object
# year                                       int64
# weekofyear                                 int64
# ndvi_ne                                  float64
# ndvi_nw                                  float64
# ndvi_se                                  float64
# ndvi_sw                                  float64
# precipitation_amt_mm                     float64
# reanalysis_air_temp_k                    float64
# reanalysis_avg_temp_k                    float64
# reanalysis_dew_point_temp_k              float64
# reanalysis_max_air_temp_k                float64
# reanalysis_min_air_temp_k                float64
# reanalysis_precip_amt_kg_per_m2          float64
# reanalysis_relative_humidity_percent     float64
# reanalysis_sat_precip_amt_mm             float64
# reanalysis_specific_humidity_g_per_kg    float64
# reanalysis_tdtr_k                        float64
# station_avg_temp_c                       float64
# ...

# %% [markdown]
# Preprocesamiento

# %%
# Eliminar 'week_start_date' solo si está presente
if "week_start_date" in features_train.columns:
    features_train.drop(columns=["week_start_date"], inplace=True)

if "week_start_date" in features_test.columns:
    features_test.drop(columns=["week_start_date"], inplace=True)

# %%
features_train = pd.get_dummies(features_train, columns=["city"], drop_first=True)
features_test = pd.get_dummies(features_test, columns=["city"], drop_first=True)

# %%
X = features_train.drop(columns=["year", "weekofyear"])
y = df_train["total_cases"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# Modelos

# %%
models = {
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest": RandomForestRegressor(),
    "Gradient Boosting": GradientBoostingRegressor()
}

# %%
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    mae = mean_absolute_error(y_val, y_pred)
    print(f"{name} MAE: {mae}")
# Out:
# Decision Tree MAE: 26.90068493150685
# Random Forest MAE: 19.294897260273974
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 for name, model in models.items():
# ----> 2     model.fit(X_train, y_train)
#       3     y_pred = model.predict(X_val)
#       4     mae = mean_absolute_error(y_val, y_pred)
#
# File c:\Users\davidrg\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# ...
